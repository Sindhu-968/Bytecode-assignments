# %% [markdown]
# <a href="https://colab.research.google.com/github/Sindhu-968/Bytecode-assignments/blob/master/Strings(16_02_26).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Python Practice - String

# %% [markdown]
# Please execute the program and check the output
# # Name  demo1.py

# %%
s="hello"
print(s)
print(type(s))
# Out:
# hello
# <class 'str'>

# %% [markdown]
# # demo2.py

# %%
s="hello"
print(length(s))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2763832739.py in <cell line: 0>()
#       1 s="hello"
# ----> 2 print(length(s))
#
# NameError: name 'length' is not defined

# %% [markdown]
# # demo3.py

# %%
s="hello"
print(len(s))
# Out:
# 5

# %% [markdown]
# # demo4.py

# %%
s1="hello"
s2="hello"
print(id(s1))
print(id(s2))
# Out:
# 138020903705680
# 138020903705680

# %% [markdown]
# # demo5.py

# %%
s1="hello"
s2="hello"
print(s1 is s2)
# Out:
# True

# %% [markdown]
# # demo6.py

# %%
s1="hello"
s2="hello"
s3="hi"
print(s1 is s2)
print(s2 is s3)
# Out:
# True
# False

# %% [markdown]
# # demo7.py

# %%
s1="hello"
s2="hello"
s3="hi"
print(s1 == s2)
print(s2 == s3)
# Out:
# True
# False

# %% [markdown]
# # demo8.py

# %%
print("a"+"bc")
# Out:
# abc

# %% [markdown]
# # demo9.py

# %%
print("abcd"[2:])
# Out:
# cd

# %% [markdown]
# # Demo10.py

# %%
str1 = 'hello'
str2 = ','
str3 = 'world'
print(str1[-1])
# Out:
# o

# %% [markdown]
# # demo11.py

# %%
print(r"\nhello")
# Out:
# \nhello

# %% [markdown]
# # demo12.py

# %%
print('new' 'line')
# Out:
# newline

# %% [markdown]
# # demo13.py

# %%
str1="helloworld"
print(str1[::-1])
# Out:
# dlrowolleh

# %% [markdown]
# # demo14.py

# %%
example = "snow world"
example[3] = 's'
print(example)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1970047547.py in <cell line: 0>()
#       1 example = "snow world"
# ----> 2 example[3] = 's'
#       3 print(example)
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# # demo15.py

# %%
l = [1, 2, 3]
print(min(l))
print(max(l))
# Out:
# 1
# 3

# %% [markdown]
# # demo16.py

# %%
q="what are you"
print(min(q)) #space ' '32
print(max(q)) #ascii value max y is 121
# Out:
#
# y

# %% [markdown]
# # demo17.py

# %%
example="hello"
print(example.count("l"))
# Out:
# 2

# %% [markdown]
# # demo18.py

# %%
example = "helle"
print(example.find("e"))
# Out:
# 1

# %% [markdown]
# # demo19.py

# %%
example = "helle"
print(example.rfind("e"))#Search from the right side and return the highest index where the substring is found.
# Out:
# 4

# %% [markdown]
# # demo20.py

# %%
example="helloworld"
print(example[::0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1615696854.py in <cell line: 0>()
#       1 example="helloworld"
# ----> 2 print(example[::0])
#
# ValueError: slice step cannot be zero

# %% [markdown]
# # demo21.py

# %%
str1="restart"
char = str1[0]
str1 = str1.replace(char, '$')
print(str1)
# Out:
# $esta$t

# %% [markdown]
# # demo22.py

# %%
str1="restart"
char = str1[0]
str1 = str1.replace(char, '$')
str2 = char + str1[1:]
print(str2)
# Out:
# resta$t

# %% [markdown]
# # demo23.py

# %%
example="helloworld"
print(example[::-1].startswith("d"))
# Out:
# True

# %% [markdown]
# # demo24.py

# %%
print("hello\example\test.txt")
# Out:
# hello\example	est.txt
# <>:1: SyntaxWarning: invalid escape sequence '\e'
# <>:1: SyntaxWarning: invalid escape sequence '\e'
# /tmp/ipython-input-2769432602.py:1: SyntaxWarning: invalid escape sequence '\e'
#   print("hello\example\test.txt")

# %% [markdown]
# # demo25.py

# %%
print("hello\\example\\test.txt")
# Out:
# hello\example\test.txt

# %% [markdown]
# # demo26.py

# %%
print("hello\"example\"test.txt")
# Out:
# hello"example"test.txt

# %% [markdown]
# # demo27.py

# %%
print("hello"\example"\test.txt")
# Out:
#   File "/tmp/ipython-input-4285170979.py", line 1
#     print("hello"\example"\test.txt")
#                   ^
# SyntaxError: unexpected character after line continuation character

# %% [markdown]
# # demo28.py

# %%
print("hello"+1+2+3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2465616466.py in <cell line: 0>()
# ----> 1 print("hello"+1+2+3)
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# # demo29.py

# %%
print("D", end = ' ')
print("C", end = ' ')
print("B", end = ' ')
print("A", end = ' ')
# Out:
# D C B A

# %% [markdown]
# # demo30.py

# %%
print("Hello".replace("l", "e"))
# Out:
# Heeeo

# %% [markdown]
# # demo31.py

# %%
print("abc DEF".capitalize())
# Out:
# Abc def

# %% [markdown]
# # demo32.py

# %%
print("abcdef".upper())
# Out:
# ABCDEF

# %% [markdown]
# # demo33.py

# %%
print("ABCDEF".upper())
# Out:
# ABCDEF

# %% [markdown]
# # demo34.py

# %%
print("ABCDEFG".lower())
# Out:
# abcdefg

# %% [markdown]
# # demo35.py

# %%
print("abcdef".center())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-186474896.py in <cell line: 0>()
# ----> 1 print("abcdef".center())
#
# TypeError: center expected at least 1 argument, got 0

# %% [markdown]
# # demo36.py

# %%
print("xyyzxyzxzxyy".count('yy'))
# Out:
# 2

# %% [markdown]
# # demo37.py

# %%
 print("xyyzxyzxzxyy".count('yy', 1))#1 is indicating from index 1
# Out:
# 2

# %% [markdown]
# # demo38.py

# %%
print("xyyzxyzxzxyy".count('yy', 4))
# Out:
# 1

# %% [markdown]
# # demo39.py

# %%
print("xyyzxyzxzxyy".endswith("xyy"))
# Out:
# True

# %% [markdown]
# # demo40.py

# %%
print("ab\tcd\tef")
# Out:
# ab	cd	ef

# %% [markdown]
# # demo41.py

# %%
print("a\nb")
# Out:
# a
# b

# %% [markdown]
# # demo42.py

# %%
  print("abcdef".find("cd"))
# Out:
# 2

# %% [markdown]
# # demo43.py

# %%
print("ccdcddcd".find("c"))
# Out:
# 0

# %% [markdown]
# # demo44.py

# %%
print("Hello {0} and {1}".format('foo', 'bin'))
# Out:
# Hello foo and bin

# %% [markdown]
# # demo45.py

# %%
print("Hello {1} and {0}".format('bin', 'foo'))
# Out:
# Hello foo and bin

# %% [markdown]
# # demo46.py

# %%
print("Hello {} and {}".format('foo', 'bin'))
# Out:
# Hello foo and bin

# %% [markdown]
# # demo47.py

# %%
print("Hello {name1} and {name2}".format('foo', 'bin'))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1896314393.py in <cell line: 0>()
# ----> 1 print("Hello {name1} and {name2}".format('foo', 'bin'))
#
# KeyError: 'name1'

# %% [markdown]
# # demo48.py

# %%
print("Hello {name1} and {name2}".format(name1='foo',name2='bin'))
# Out:
# Hello foo and bin

# %% [markdown]
# # demo49.py

# %%
print('The sum of {0} and {1} is {2}'.format(2, 10, 12))
# Out:
# The sum of 2 and 10 is 12

# %% [markdown]
# # demo50.py

# %%
print('ab12'.isalnum())
# Out:
# True

# %% [markdown]
# # demo51.py

# %%
print('ab,12'.isalnum())
# Out:
# False

# %% [markdown]
# # demo52.py

# %%
print('ab'.isalpha())
# Out:
# True

# %% [markdown]
# # demo53.py

# %%
print('a B'.isalpha())
# Out:
# False

# %% [markdown]
# # demo54.py

# %%
print('0xa'.isdigit())
# Out:
# False

# %% [markdown]
# # demo55.py

# %%
print(''.isdigit())
# Out:
# False

# %% [markdown]
# # demo56.py

# %%
print('my_string'.isidentifier())
# Out:
# True

# %% [markdown]
# # demo57.py

# %%
print('$my_string'.isidentifier())
# Out:
# False

# %% [markdown]
# # demo58.py

# %%
print('abc'.islower())
# Out:
# True

# %% [markdown]
# # demo59.py

# %%
print('a@1,'.islower())
# Out:
# True

# %% [markdown]
# # demo60.py

# %%
print('11'.isnumeric())
# Out:
# True

# %% [markdown]
# # demo61.py

# %%
print('HelloWorld'.istitle())
# Out:
# False

# %% [markdown]
# # demo62.py

# %%
print('Hello World'.istitle())
# Out:
# True

# %% [markdown]
# # demo63.py

# %%
s1=''' hello  hi how are you'''
print(s1)
# Out:
#  hello  hi how are you

# %% [markdown]
# # demo64.py

# %%
s1='''     hello hi how are you'''
print(s1.strip())
# Out:
# hello hi how are you

# %% [markdown]
# # demo65.py

# %%
print('abcdef'.partition('cd')) # it divide 3 parts (partition means it divide 3 parts)
# Out:
# ('ab', 'cd', 'ef')

# %% [markdown]
# # demo66.py

# %%
print('abcdefcdgh'.partition('cd'))
# Out:
# ('ab', 'cd', 'efcdgh')

# %% [markdown]
# # demo67.py

# %%
print('abcd'.partition('cd'))
# Out:
# ('ab', 'cd', '')

# %% [markdown]
# # demo68.py

# %%
print('abcdef12'.replace('cd', '12'))
# Out:
# ab12ef12

# %% [markdown]
# # demo69.py

# %%
print('abef'.replace('cd', '12'))
# Out:
# abef

# %% [markdown]
# # demo70.py

# %%
print('abcdefcdghcd'.split('cd'))
# Out:
# ['ab', 'ef', 'gh', '']
